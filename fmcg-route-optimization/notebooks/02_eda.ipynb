# %% [markdown]
# imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# load datasets

# %%
depots = pd.read_csv("/workspaces/FMCG---Route-Optimization-for-Sustainability/fmcg-route-optimization/data/raw/depots.csv")
customers = pd.read_csv("/workspaces/FMCG---Route-Optimization-for-Sustainability/fmcg-route-optimization/data/raw/customers.csv")
orders = pd.read_csv("/workspaces/FMCG---Route-Optimization-for-Sustainability/fmcg-route-optimization/data/raw/orders.csv")
vehicles = pd.read_csv("/workspaces/FMCG---Route-Optimization-for-Sustainability/fmcg-route-optimization/data/raw/vehicles.csv")

# %% [markdown]
# Basic stats

# %%
print("Depots:", len(depots))
print("Customers:", len(customers))
print("Orders:", len(orders))
print("Vehicles:", len(vehicles))

print("\nOrders Summary:")
print(orders[["demand_units","service_minutes"]].describe())
# Out:
# Depots: 15
# Customers: 50000
# Orders: 120000
# Vehicles: 3000
#
# Orders Summary:
#         demand_units  service_minutes
# count  120000.000000    120000.000000
# mean      252.011058        14.476558
# std       142.621918         5.771285
# min         5.000000         5.000000
# 25%       129.000000         9.000000
# 50%       252.000000        14.000000
# 75%       375.000000        19.000000
# max       499.000000        24.000000

# %% [markdown]
# Demand distribution

# %%
plt.figure(figsize=(8,5))
sns.histplot(orders["demand_units"], bins=30, kde=True)
plt.title("Order Demand Distribution")
plt.show()

# %% [markdown]
# Vehicle capacity distribution

# %%
plt.figure(figsize=(8,5))
sns.histplot(vehicles["capacity_units"], bins=20, kde=False)
plt.title("Vehicle Capacity Distribution")
plt.show()

# %% [markdown]
# Temp zone breakdown

# %%
sns.countplot(x="temp_zone", data=orders)
plt.title("Orders by Temperature Zone")
plt.show()

# %% [markdown]
# Priority breakdown

# %%
sns.countplot(x="priority", data=orders)
plt.title("Orders by Priority Level")
plt.show()
